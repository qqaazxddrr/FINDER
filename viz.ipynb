# %%
import matplotlib.pyplot as plt

# %%
file_1=open('Result/ModelVC_30_50_1.csv')
file_2=open('Result/ModelVC_30_50_2.csv')

# %%
data_1=file_1.readline()
data_2=file_2.readline()
file_1.close()
file_2.close()

# %%
data_1=data_1.split()
data_2=data_2.split()

# %%
data_1=[float(i) for i in data_1]
data_2=[float(i) for i in data_2]

# %%
plt.plot(data_1)
plt.plot(data_2)
